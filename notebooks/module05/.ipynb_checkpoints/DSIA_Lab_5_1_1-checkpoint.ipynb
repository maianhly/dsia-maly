# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#1.-Load-Data" data-toc-modified-id="1.-Load-Data-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>1. Load Data</a></span></li><li><span><a href="#2.-EDA" data-toc-modified-id="2.-EDA-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>2. EDA</a></span><ul class="toc-item"><li><span><a href="#Check-for-null-or-missing-values" data-toc-modified-id="Check-for-null-or-missing-values-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Check for null or missing values</a></span></li><li><span><a href="#Initial-EDA" data-toc-modified-id="Initial-EDA-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Initial EDA</a></span></li><li><span><a href="#Convert-diagnosis-column-to-binary-values" data-toc-modified-id="Convert-diagnosis-column-to-binary-values-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Convert diagnosis column to binary values</a></span></li></ul></li><li><span><a href="#3.-Logistic-Regression-Model" data-toc-modified-id="3.-Logistic-Regression-Model-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>3. Logistic Regression Model</a></span><ul class="toc-item"><li><span><a href="#3.1-Use-Logistic-Regression" data-toc-modified-id="3.1-Use-Logistic-Regression-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>3.1 Use Logistic Regression</a></span></li><li><span><a href="#3.2-Calculate-the-predicted-labels-and-predicted-probabilities-on-the-test-set." data-toc-modified-id="3.2-Calculate-the-predicted-labels-and-predicted-probabilities-on-the-test-set.-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>3.2 Calculate the predicted labels and predicted probabilities on the test set.</a></span></li><li><span><a href="#3.3-Create-the-confusion-matrix-for-your-classfier's-performance-on-the-test-set." data-toc-modified-id="3.3-Create-the-confusion-matrix-for-your-classfier's-performance-on-the-test-set.-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>3.3 Create the confusion matrix for your classfier's performance on the test set.</a></span></li><li><span><a href="#3.4-Calculate-Accuracy" data-toc-modified-id="3.4-Calculate-Accuracy-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>3.4 Calculate Accuracy</a></span></li><li><span><a href="#3.5-Calculate-Classification-Error" data-toc-modified-id="3.5-Calculate-Classification-Error-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>3.5 Calculate Classification Error</a></span></li><li><span><a href="#3.6-Calculate-Sensitivity" data-toc-modified-id="3.6-Calculate-Sensitivity-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>3.6 Calculate Sensitivity</a></span></li><li><span><a href="#3.7-Calculate-Specificity" data-toc-modified-id="3.7-Calculate-Specificity-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>3.7 Calculate Specificity</a></span></li><li><span><a href="#3.8-Calculate-False-Positive-Rate" data-toc-modified-id="3.8-Calculate-False-Positive-Rate-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>3.8 Calculate False Positive Rate</a></span></li><li><span><a href="#3.9-Calculate-Precision" data-toc-modified-id="3.9-Calculate-Precision-3.9"><span class="toc-item-num">3.9&nbsp;&nbsp;</span>3.9 Calculate Precision</a></span></li><li><span><a href="#3.10-Create-a-predicted-test-probability-dataframe-with-column-name-'class_0_pp','class_1_pp'" data-toc-modified-id="3.10-Create-a-predicted-test-probability-dataframe-with-column-name-'class_0_pp','class_1_pp'-3.10"><span class="toc-item-num">3.10&nbsp;&nbsp;</span>3.10 Create a predicted test probability dataframe with column name 'class_0_pp','class_1_pp'</a></span></li><li><span><a href="#3.11-The-Receiver-operating-characteristic-(ROC)-curve" data-toc-modified-id="3.11-The-Receiver-operating-characteristic-(ROC)-curve-3.11"><span class="toc-item-num">3.11&nbsp;&nbsp;</span>3.11 The Receiver operating characteristic (ROC) curve</a></span></li></ul></li></ul></div>

# %% [markdown]
# ![alt text](https://i.imgur.com/1WaY7aA.png)

# %% [markdown]
# # Lab 5.1.1
# # *Evaluating Classification Models*
#
# In this lab you will be practicing evaluating classification models (Logistic Regression in particular) on a "Breast Cancer" data.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.datasets import make_blobs

# %matplotlib inline

# %% [markdown]
# ### 1. Load Data
#
# Features are computed from a digitized image of a fine needle aspirate (FNA) of a breast mass. They describe characteristics of the cell nuclei present in the image. n the 3-dimensional space is that described in: [K. P. Bennett and O. L. Mangasarian: "Robust Linear Programming Discrimination of Two Linearly Inseparable Sets", Optimization Methods and Software 1, 1992, 23-34].
#
# This database is also available through the UW CS ftp server: ftp ftp.cs.wisc.edu cd math-prog/cpo-dataset/machine-learn/WDBC/
#
# Also can be found on UCI Machine Learning Repository: https://archive.ics.uci.edu/ml/datasets/Breast+Cancer+Wisconsin+%28Diagnostic%29
#
# Attribute Information:
#
# 1) ID number 2) Diagnosis (M = malignant, B = benign) 3-32)
#
# Ten real-valued features are computed for each cell nucleus:
#
#     a) radius (mean of distances from center to points on the perimeter)
#     b) texture (standard deviation of gray-scale values)
#     c) perimeter
#     d) area
#     e) smoothness (local variation in radius lengths)
#     f) compactness (perimeter^2 / area - 1.0)
#     g) concavity (severity of concave portions of the contour)
#     h) concave points (number of concave portions of the contour)
#     i) symmetry
#     j) fractal dimension ("coastline approximation" - 1)
#
# The mean, standard error and "worst" or largest (mean of the three largest values) of these features were computed for each image, resulting in 30 features. For instance, field 3 is Mean Radius, field 13 is Radius SE, field 23 is Worst Radius.
#
# All feature values are recoded with four significant digits.
#
# Missing attribute values: none
#
# Class distribution: 357 benign, 212 malignant

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
breast_cancer_csv = pd.read_csv('../../data/breast-cancer-wisconsin-data.csv')

breast_cancer_csv.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
# Drop last column

breast_cancer_csv = breast_cancer_csv.drop('Unnamed: 32', axis=1)

# %% [markdown]
# ### 2. EDA
#
# Explore dataset. Check for nulls. Make the target column binary.

# %% [markdown]
# #### Check for null or missing values

# %%
# Check for NaN values

breast_cancer_csv.isnull().sum()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %%
# check min of all float cols: are they >= 0?

breast_cancer_csv.select_dtypes(include='float').min(axis=0)
# Out:
# radius_mean                  6.981000
# texture_mean                 9.710000
# perimeter_mean              43.790000
# area_mean                  143.500000
# smoothness_mean              0.052630
# compactness_mean             0.019380
# concavity_mean               0.000000
# concave points_mean          0.000000
# symmetry_mean                0.106000
# fractal_dimension_mean       0.049960
# radius_se                    0.111500
# texture_se                   0.360200
# perimeter_se                 0.757000
# area_se                      6.802000
# smoothness_se                0.001713
# compactness_se               0.002252
# concavity_se                 0.000000
# concave points_se            0.000000
# symmetry_se                  0.007882
# fractal_dimension_se         0.000895
# radius_worst                 7.930000
# texture_worst               12.020000
# perimeter_worst             50.410000
# area_worst                 185.200000
# smoothness_worst             0.071170
# ...

# %%
# Check if values in id col are unique

len(breast_cancer_csv) == len(breast_cancer_csv['id'].unique())
# Out:
# True

# %% [markdown]
# #### Initial EDA

# %%
breast_cancer_csv.shape
# Out:
# (569, 32)

# %%
breast_cancer_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
# id                         569 non-null int64
# diagnosis                  569 non-null object
# radius_mean                569 non-null float64
# texture_mean               569 non-null float64
# perimeter_mean             569 non-null float64
# area_mean                  569 non-null float64
# smoothness_mean            569 non-null float64
# compactness_mean           569 non-null float64
# concavity_mean             569 non-null float64
# concave points_mean        569 non-null float64
# symmetry_mean              569 non-null float64
# fractal_dimension_mean     569 non-null float64
# radius_se                  569 non-null float64
# texture_se                 569 non-null float64
# perimeter_se               569 non-null float64
# area_se                    569 non-null float64
# smoothness_se              569 non-null float64
# ...

# %%
breast_cancer_csv.select_dtypes(include='float').describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
# Check for correlations 

plt.figure(figsize=(10, 10))
sns.heatmap(breast_cancer_csv.select_dtypes(include='float').corr(), linewidths=0.2, cmap='RdBu')
plt.show()

# %% [markdown]
# High positive correlation:
#
# - Radius, area and perimeter means
# - Radius, area and perimeter worsts
# - Radius, area and perimeter means with radius, area and perimeter worsts
#
# High negative correlation:
#
# - Fractal dimension mean/se/worst with radius/area/perimeter/texture mean/worst
# - Smoothness mean/se with radius/area/perimeter/texture mean/worst
# - Symmetry se with radius/area/perimeter/texture mean/worst
# - Symmetry mean with radius/area/perimeter/texture worst

# %%
pos_cols = ['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 
            'radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst']

sns.pairplot(breast_cancer_csv[pos_cols])
plt.show()

# %%
neg_cols = ['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 
            'radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst',
            'fractal_dimension_mean', 'symmetry_mean', 'smoothness_mean']

sns.pairplot(breast_cancer_csv[neg_cols])
plt.show()

# %% [markdown]
# #### Convert diagnosis column to binary values

# %%
# Check value counts for diagnosis

breast_cancer_csv['diagnosis'].value_counts(dropna=False)
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
# Convert diagnosis to binary

breast_cancer_csv['target'] = breast_cancer_csv['diagnosis'].apply(lambda x: 1 if x == 'M' else 0)

# Value counts for target should be same as diagnosis col

breast_cancer_csv['target'].value_counts()
# Out:
# 0    357
# 1    212
# Name: target, dtype: int64

# %% [markdown]
# ### 3. Logistic Regression Model
#
# #### 3.1 Use Logistic Regression
#
# Use Logistic Regression and examine accuracy score, confusion matrix, classification report for that model.

# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import confusion_matrix, roc_curve, auc, precision_score, recall_score
from sklearn.linear_model import LogisticRegression

# %%
# Choose predictors and features

X = breast_cancer_csv.drop(['id', 'diagnosis', 'target'], axis=1)
y = breast_cancer_csv['target']

# Split data

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=21)

# fit model

logreg = LogisticRegression(solver='liblinear')

logreg.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %% [markdown]
# #### 3.2 Calculate the predicted labels and predicted probabilities on the test set.

# %%
# predict test class:

preds = logreg.predict(X_test)

# predicted test probability:

probs = logreg.predict_proba(X_test)

# %% [markdown]
# #### 3.3 Create the confusion matrix for your classfier's performance on the test set.
#
# Convert confusion_matrix to a dataframe.
#
#     index=['is_cancer', 'is_healthy']
#     columns=['predicted_cancer','predicted_healthy']

# %%
# ANSWER

conf_mat = pd.DataFrame(confusion_matrix(y_test, preds), 
                        index=['is_cancer', 'is_healthy'], 
                        columns=['predicted_cancer', 'predicted_healthy'])

conf_mat
# Out:
#             predicted_cancer  predicted_healthy
# is_cancer                 88                  2
# is_healthy                 3                 50

# %% [markdown]
# #### 3.4 Calculate Accuracy
#
# **Classification Accuracy:** Overall, how often is the classifier correct?
#
#     (TP + TN) / float(TP + TN + FP + FN)

# %%
# ANSWER
# use float to perform true division, not integer division

# unpack confusion_matrix

tn, fp, fn, tp = confusion_matrix(y_test, preds).ravel()

# calculate accuracy

print("Calculated accuracy: ", (tp + tn) / (tp + tn + fp + fn))
print("Calculated via .score: ", logreg.score(X_test, y_test))
# Out:
# Calculated accuracy:  0.965034965034965
# Calculated via .score:  0.965034965034965

# %% [markdown]
# #### 3.5 Calculate Classification Error
#
# **Classification Error:** Overall, how often is the classifier incorrect?
#
# Also known as "Misclassification Rate"
#
#     (FP + FN) / float(TP + TN + FP + FN)

# %%
# ANSWER

print("Misclassification rate:", (fp + fn) / (tp + tn + fp + fn))
print("1 - accuracy:", 1 - logreg.score(X_test, y_test))
# Out:
# Misclassification rate: 0.03496503496503497
# 1 - accuracy: 0.034965034965035

# %% [markdown]
# #### 3.6 Calculate Sensitivity
#
# **Sensitivity:** When the actual value is positive, how often is the prediction correct?
#
# Something we want to maximize
# How "sensitive" is the classifier to detecting positive instances?
# - Also known as "True Positive Rate" or "Recall"
# - TP / all positive
#     - all positive = TP + FN
#
#     sensitivity = TP / float(FN + TP)

# %%
# ANSWER

print("Sensitivity: ", (tp) / (tp + fn))
# Out:
# Sensitivity:  0.9433962264150944

# %% [markdown]
# #### 3.7 Calculate Specificity
#
# **Specificity:** When the actual value is negative, how often is the prediction correct?
#
# - Something we want to maximize. How "specific" (or "selective") is the classifier in predicting positive instances?
# - TN / all negative
#     - all negative = TN + FP
#
#     specificity = TN / (TN + FP)

# %%
# ANSWER

print("Specificity: ", tn / (tn + fp))
# Out:
# Specificity:  0.9777777777777777

# %% [markdown]
# #### 3.8 Calculate False Positive Rate
#
# **False Positive Rate:** When the actual value is negative, how often is the prediction incorrect?
#
#     false_positive_rate = FP / float(TN + FP)

# %%
# ANSWER

print("False positive rate: ", fp / (tn + tp))
# Out:
# False positive rate:  0.014492753623188406

# %% [markdown]
# #### 3.9 Calculate Precision
#
# **Precision:** When a positive value is predicted, how often is the prediction correct?
#
# How "precise" is the classifier when predicting positive instances?
#
#     precision = TP / float(TP + FP)

# %%
# ANSWER

print("Precision: ", tp / (tp + fp))
print("precision_score: ",  precision_score(y_test, preds))
# Out:
# Precision:  0.9615384615384616
# precision_score:  0.9615384615384616

# %% [markdown]
# #### 3.10 Create a predicted test probability dataframe with column name 'class_0_pp','class_1_pp'

# %%
# ANSWER
# Get the predicted probability vector and explicitly name the columns:)

probs_df = pd.DataFrame({'class_0_pp': probs[:, 0],
                         'class_1_pp': probs[:, 1]})

probs_df.head()
# Out:
#    class_0_pp  class_1_pp
# 0    0.000867    0.999133
# 1    0.013075    0.986925
# 2    0.253359    0.746641
# 3    0.211270    0.788730
# 4    0.654260    0.345740

# %% [markdown]
# #### 3.11 The Receiver operating characteristic (ROC) curve
#
# Plot the ROC curve for Class 1

# %%
# For class 1, find the area under the curve
# Find fpr, tpr

fpr, tpr, thresholds = roc_curve(y_test, probs_df['class_1_pp'])

# Find auc
roc_auc = auc(fpr, tpr)

# Plot of a ROC curve for class 1 (has_cancer)
plt.figure(figsize=[8,8])

# Plot fpr, tpr

plt.plot(fpr, tpr, color='darkorange', lw=4, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--', linewidth=4)
plt.xlim([-0.05, 1.0])
plt.ylim([-0.05, 1.05])
plt.xlabel('False Positive Rate', fontsize=18)
plt.ylabel('True Positive Rate', fontsize=18)
plt.title('Receiver operating characteristic for cancer detection', fontsize=18)
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# **References**
#
# [Breast Cancer Wisconsin (Diagnostic) Data Set](https://www.kaggle.com/uciml/breast-cancer-wisconsin-data/downloads/breast-cancer-wisconsin-data.zip/2)
#
# [Validation curves: plotting scores to evaluate models](https://scikit-learn.org/stable/modules/learning_curve.html#learning-curves)

# %% [markdown]
# **© 2019 Data Science Institute of Australia**
