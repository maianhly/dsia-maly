# %% [markdown]
# ![alt text](https://i.imgur.com/1WaY7aA.png)
#
#
# ---
#
#
#
# ---

# %% [markdown]
# # Lab 2.1.5
# # *Neo4j and Python*

# %% [markdown]
# ## Introduction
#
# Neo4j is the most popular graph database. Free versions include the Desktop (Developer) edition and the Community Server edition (which we can drive from Python).
#
# We will begin this lab by working through the tutorial embedded in the Neo4j *start* page to learn about graph databases structures and the Cypher query language. We will then see how to integrate a Neo4j database with a Python program.

# %% [markdown]
# The Community Server version can be downloaded here: https://neo4j.com/download-center/#releases
# ![image.png](attachment:image.png)

# %% [markdown]
# - Go through the *Concepts* tutorial.
# - At the end, click *Intro* under *Keep getting started* heading and go through the tutorial.
# - At the end, click *Cypher* under *Keep getting started* heading and go through the tutorial.
# - At the end, click *The Movie Graph* under *Jump into code* heading and go through the tutorial.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Driving Neo4j from Python
#
# There are a variety of Python libraries for Neo4j, some of which provide more compact (and simpler) ways of executing commands. To avoid having to learn too many different ways of doing the same thing, however, we will use the official one, which is based on the syntax of the Cypher query language.

# %%
# !pip install neo4j
# Out:
# Collecting neo4j
#   Downloading https://files.pythonhosted.org/packages/f5/ec/0122e0e032b79f5ae7a2e46836027cf817ee5a10be89130d69799ae1ad74/neo4j-1.7.2.tar.gz
# Collecting neobolt<2,>=1.7.4 (from neo4j)
#   Downloading https://files.pythonhosted.org/packages/ba/02/641c5241db092f75bce1334cb728d3fb48f4dddc5d21401fe94a5ed636ad/neobolt-1.7.4.tar.gz (182kB)
#     100% |████████████████████████████████| 184kB 6.6MB/s
# Collecting neotime<2,>=1.7.1 (from neo4j)
#   Downloading https://files.pythonhosted.org/packages/0b/7e/ca368a8d8e288be1352d4e2df35da1e01f8aaffbf526695df71630bcb8a6/neotime-1.7.4.tar.gz
# Requirement already satisfied: pytz in /usr/local/lib/python3.6/dist-packages (from neotime<2,>=1.7.1->neo4j) (2018.9)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from neotime<2,>=1.7.1->neo4j) (1.11.0)
# Building wheels for collected packages: neo4j, neobolt, neotime
#   Building wheel for neo4j (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/91/ba/0d/af2e696b035cd8997f7a524742896b904078e334124463c0d3
#   Building wheel for neobolt (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/29/15/1f/a2d381d5186d84b524791cc3eff45e0e01645a8412e20a1658
#   Building wheel for neotime (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/d4/b4/c4/ab867cd0ac9e667f8cd269f9364fd1cb8ee75fe50f5ce97c79
# Successfully built neo4j neobolt neotime
# Installing collected packages: neobolt, neotime, neo4j
# Successfully installed neo4j-1.7.2 neobolt-1.7.4 neotime-1.7.4

# %% [markdown]
# The ***Neo4j Bolt Driver for Python*** is documented at https://neo4j.com/docs/api/python-driver/current/.

# %%
from neo4j.v1 import GraphDatabase

uri = "bolt://localhost:7687"

# %%
driver = GraphDatabase.driver(uri, auth=("neo4j", "Windows_bites"))
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/neobolt/direct.py in _connect(resolved_address, **config)
#     808         log_debug("[#0000]  C: <OPEN> %s", resolved_address)
# --> 809         s.connect(resolved_address)
#     810         s.settimeout(t)
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# ServiceUnavailable                        Traceback (most recent call last)
# <ipython-input-5-b8a4dc129cd7> in <module>()
# ----> 1 driver = GraphDatabase.driver(uri, auth=("neo4j", "Windows_bites"))
#
# /usr/local/lib/python3.6/dist-packages/neo4j/__init__.py in driver(cls, uri, **config)
#     106         :class:`.Driver` subclass instance directly.
#     107         """
# --> 108         return Driver(uri, **config)
#     109
#     110
#
# /usr/local/lib/python3.6/dist-packages/neo4j/__init__.py in __new__(cls, uri, **config)
#     145         for subclass in Driver.__subclasses__():
#     146             if parsed.scheme == subclass.uri_scheme:
# --> 147                 return subclass(uri, **config)
#     148         raise ValueError("URI scheme %r not supported" % parsed.scheme)
#     149
#
# /usr/local/lib/python3.6/dist-packages/neo4j/__init__.py in __new__(cls, uri, **config)
#     219
#     220         pool = ConnectionPool(connector, instance.address, **config)
# --> 221         pool.release(pool.acquire())
#     222         instance._pool = pool
#     223         instance._max_retry_time = config.get("max_retry_time", default_config["max_retry_time"])
#
# /usr/local/lib/python3.6/dist-packages/neobolt/direct.py in acquire(self, access_mode)
#     696
#     697     def acquire(self, access_mode=None):
# --> 698         return self.acquire_direct(self.address)
#     699
#     700
#
# /usr/local/lib/python3.6/dist-packages/neobolt/direct.py in acquire_direct(self, address)
#     589                 if can_create_new_connection:
#     590                     try:
# --> 591                         connection = self.connector(address, error_handler=self.connection_error_handler)
#     592                     except ServiceUnavailable:
#     593                         self.remove(address)
#
# /usr/local/lib/python3.6/dist-packages/neo4j/__init__.py in connector(address, **kwargs)
#     216
#     217         def connector(address, **kwargs):
# --> 218             return connect(address, **dict(config, **kwargs))
#     219
#     220         pool = ConnectionPool(connector, instance.address, **config)
#
# /usr/local/lib/python3.6/dist-packages/neobolt/direct.py in connect(address, **config)
#     947         raise ServiceUnavailable("Failed to resolve addresses for %s" % address)
#     948     else:
# --> 949         raise last_error
#
# /usr/local/lib/python3.6/dist-packages/neobolt/direct.py in connect(address, **config)
#     937     for resolved_address in resolver.addresses:
#     938         try:
# --> 939             s = _connect(resolved_address, **config)
#     940             s, der_encoded_server_certificate = _secure(s, address[0], security_plan.ssl_context, **config)
#     941             connection = _handshake(s, resolved_address, der_encoded_server_certificate, **config)
#
# /usr/local/lib/python3.6/dist-packages/neobolt/direct.py in _connect(resolved_address, **config)
#     819         log_debug("[#0000]  C: <CLOSE> %s", resolved_address)
#     820         s.close()
# --> 821         raise ServiceUnavailable("Failed to establish connection to {!r} (reason {})".format(resolved_address, error))
#     822     else:
#     823         return s
#
# ServiceUnavailable: Failed to establish connection to ('127.0.0.1', 7687) (reason [Errno 111] Connection refused)

# %% [markdown]
# To execute a query against a database using this driver, we need to wrap the Cypher query string in a function definition and pass the function to the `read_transaction` method of the `session` object. Our query function then has access to the `tx` object.
#
# Here is a function that finds all the movies that the requested `Person` acted in:

# %%
def print_movies_by(tx, name):
    for record in tx.run("MATCH (a:Person)-[:ACTED_IN]->(anyMovies) "
                         "WHERE a.name = {name} "
                         "RETURN anyMovies", name = name):
        print(record["anyMovies"])

# %% [markdown]
# Here is how to use it to list Tom Hanks' movies:

# %%
with driver.session() as session:
    session.read_transaction(print_movies_by, "Tom Hanks")

# %% [markdown]
# Clearly, some further wrangling is required to produce neat output. (Read the documentation before you attempt this.)

# %% [markdown]
# In fact, both the method of using the Neo4j Bolt Driver and the data returned by it are unwieldy. This is typical of low-level drivers.

# %% [markdown]
# Try building and running some more queries based on the code in examples queries in The Movie Graph tutorial.

# %% [markdown]
# ## - END -

# %% [markdown]
# >

# %% [markdown]
# >

# %% [markdown]
# >

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2019 Data Science Institute of Australia
#
#
# ---
#
#
#
# ---
